# %%
# %run NewChartsWorking.ipynb
# Out:
# ./output-20-02/merged/*.txt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/workspace/repro-paper-51-ALENEX26-/NotebooksPerFigureType/NewChartsWorking.ipynb in <module>
#       6 dfs=read_dfs(path,patterndevs, 2)
#       7 labels = ['A1', 'A2', 'A3', 'BASE']
# ----> 8 dfsVar1 = [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')]]
#       9 #print(dfsVar1)
#      10
#
# KeyError: ('A1', 'ndev')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27473/4088262980.py in <module>
# ----> 1 get_ipython().run_line_magic('run', 'NewChartsWorking.ipynb')
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# ~/anaconda3/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2836                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2837                     if raise_exceptions:
# -> 2838                         result.raise_error()
#    2839                     elif not result.success:
#    2840                         break
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in raise_error(self)
#     330             raise self.error_before_exec
#     331         if self.error_in_exec is not None:
# --> 332             raise self.error_in_exec
#     333
#     334     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_27473/1262915414.py in <module>
#       6 dfs=read_dfs(path,patterndevs, 2)
#       7 labels = ['A1', 'A2', 'A3', 'BASE']
# ----> 8 dfsVar1 = [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')]]
#       9 #print(dfsVar1)
#      10
#
# KeyError: ('A1', 'ndev')

# %%
path = "./output-all-minweights/merged/*.txt" #"./output-28-03/merged/*.txt"
print(path)

print("\n-----------------\n all by 19.04 with smallest edge weights \n With A4 and A5, all deviations \n  Release enough to fill our processor\n With smallest edge weight on all edges")
patterndevs = r'^(BASE|A\d+)-(ndev)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')], dfs[('A4','ndev')], dfs[('A5','ndev')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)
merged_df_varOurProcNoDev["online_to_offline_A2"] = merged_df_varOurProcNoDev["ms_1_A2"]/merged_df_varOurProcNoDev["ms_2_A2"]
merged_df_varOurProcNoDev["offline_to_base_A2"] = merged_df_varOurProcNoDev["ms_2_A2"]/merged_df_varOurProcNoDev["ms_2_A1"]


merged_df_varOurProcNoDev["online_to_offline_A1"] = merged_df_varOurProcNoDev["ms_1_A1"]/merged_df_varOurProcNoDev["ms_2_A1"]
merged_df_varOurProcNoDev["offline_to_base_A1"] = merged_df_varOurProcNoDev["ms_2_A1"]/merged_df_varOurProcNoDev["ms_2_A1"]
print("online_to_offline_A1", merged_df_varOurProcNoDev["online_to_offline_A1"].agg(gmean))
print("offline_to_base_A1", merged_df_varOurProcNoDev["offline_to_base_A1"].agg(gmean))

patterndevs = r'^(BASE|A\d+)-(\d\ddev)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev')], dfs[('A2','50dev')], dfs[('A3','50dev')], dfs[('A4','50dev')], dfs[('A5','50dev')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)


merged_df_varOurProcNoDev["online_to_offline_A2"] = merged_df_varOurProcNoDev["ms_1_A2"]/merged_df_varOurProcNoDev["ms_2_A2"]
merged_df_varOurProcNoDev["offline_to_base_A2"] = merged_df_varOurProcNoDev["ms_2_A2"]/merged_df_varOurProcNoDev["ms_2_A1"]
print("online_to_offline_A2", merged_df_varOurProcNoDev["online_to_offline_A2"].agg(gmean))
print("offline_to_base_A2", merged_df_varOurProcNoDev["offline_to_base_A2"].agg(gmean))


merged_df_OurProc50["online_to_offline_A2"] = merged_df_OurProc50["ms_1_A2"]/merged_df_OurProc50["ms_2_A2"]
merged_df_OurProc50["offline_to_base_A2"] = merged_df_OurProc50["ms_2_A2"]/merged_df_OurProc50["ms_2_A1"]
print("online_to_offline_A2 50-vars", merged_df_OurProc50["online_to_offline_A2"].agg(gmean))
print("offline_to_base_A2 50-vars",merged_df_OurProc50["offline_to_base_A2"].agg(gmean))

print("\n------------------------------------\n")


merged_df_varOurProcNoDev["online_to_offline_A3"] = merged_df_varOurProcNoDev["ms_1_A3"]/merged_df_varOurProcNoDev["ms_2_A3"]
merged_df_varOurProcNoDev["offline_to_base_A3"] = merged_df_varOurProcNoDev["ms_2_A3"]/merged_df_varOurProcNoDev["ms_2_A1"]
print("online_to_offline_A3", merged_df_varOurProcNoDev["online_to_offline_A3"].agg(gmean))
print("offline_to_base_A3", merged_df_varOurProcNoDev["offline_to_base_A3"].agg(gmean))


merged_df_OurProc50["online_to_offline_A3"] = merged_df_OurProc50["ms_1_A3"]/merged_df_OurProc50["ms_2_A3"]
merged_df_OurProc50["offline_to_base_A3"] = merged_df_OurProc50["ms_2_A3"]/merged_df_OurProc50["ms_2_A1"]
print("online_to_offline_A3 50-vars", merged_df_OurProc50["online_to_offline_A3"].agg(gmean))
print("offline_to_base_A3 50-vars",merged_df_OurProc50["offline_to_base_A3"].agg(gmean))



print("\n------------------------------------\n")


merged_df_varOurProcNoDev["online_to_offline_A4"] = merged_df_varOurProcNoDev["ms_1_A4"]/merged_df_varOurProcNoDev["ms_2_A4"]
merged_df_varOurProcNoDev["offline_to_base_A4"] = merged_df_varOurProcNoDev["ms_2_A4"]/merged_df_varOurProcNoDev["ms_2_A1"]
print("online_to_offline_A4", merged_df_varOurProcNoDev["online_to_offline_A4"].agg(gmean))
print("offline_to_base_A4", merged_df_varOurProcNoDev["offline_to_base_A4"].agg(gmean))


merged_df_OurProc50["online_to_offline_A4"] = merged_df_OurProc50["ms_1_A4"]/merged_df_OurProc50["ms_2_A4"]
merged_df_OurProc50["offline_to_base_A4"] = merged_df_OurProc50["ms_2_A4"]/merged_df_OurProc50["ms_2_A1"]
print("online_to_offline_A4 50-vars", merged_df_OurProc50["online_to_offline_A4"].agg(gmean))
print("offline_to_base_A4 50-vars",merged_df_OurProc50["offline_to_base_A4"].agg(gmean))



print("\n------------------------------------\n")

merged_df_varOurProcNoDev["online_to_offline_A5"] = merged_df_varOurProcNoDev["ms_1_A5"]/merged_df_varOurProcNoDev["ms_2_A5"]
merged_df_varOurProcNoDev["offline_to_base_A5"] = merged_df_varOurProcNoDev["ms_2_A5"]/merged_df_varOurProcNoDev["ms_2_A1"]
print("online_to_offline_A5", merged_df_varOurProcNoDev["online_to_offline_A5"].agg(gmean))
print("offline_to_base_A5", merged_df_varOurProcNoDev["offline_to_base_A5"].agg(gmean))



merged_df_OurProc50["online_to_offline_A5"] = merged_df_OurProc50["ms_1_A5"]/merged_df_OurProc50["ms_2_A5"]
merged_df_OurProc50["offline_to_base_A5"] = merged_df_OurProc50["ms_2_A5"]/merged_df_OurProc50["ms_2_A1"]
print("online_to_offline_A5 50-vars", merged_df_OurProc50["online_to_offline_A5"].agg(gmean))
print("offline_to_base_A5 50-vars",merged_df_OurProc50["offline_to_base_A5"].agg(gmean))
# Out:
# ./output-all-minweights/merged/*.txt
#
# -----------------
#  all by 19.04 with smallest edge weights
#  With A4 and A5, all deviations
#   Release enough to fill our processor
#  With smallest edge weight on all edges
# online_to_offline_A1 1.075571941627209
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 1.0755850361367212
# offline_to_base_A2 1.000100632249225
# online_to_offline_A2 50-vars 0.8973440553526705
# offline_to_base_A2 50-vars 0.9962928434788929
#
# ------------------------------------
#
# online_to_offline_A3 0.3739708457273067
# offline_to_base_A3 2.8949000887036074
# online_to_offline_A3 50-vars 0.3242535260691822
# offline_to_base_A3 50-vars 2.8036963068165854
#
# ------------------------------------
#
# online_to_offline_A4 0.9115175008121664
# offline_to_base_A4 1.2012123093894747
# online_to_offline_A4 50-vars 0.7473084303052873
# offline_to_base_A4 50-vars 1.2035378778012604
#
# ------------------------------------
#
# online_to_offline_A5 0.43674964712608166
# offline_to_base_A5 2.5082886577886474
# online_to_offline_A5 50-vars 0.36860921984643524
# offline_to_base_A5 50-vars 2.4348077769207226

# %%
# %run NewChartsCommon.ipynb
plot_df_nodev  = build_plot_df_size_categories(merged_df_varOurProcNoDev) # buld_plot_df(merged_df_varOurProcNoDev)
print(plot_df_nodev.columns)

plotDynVsBaseCustomLegend(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')
plt.savefig(f'NoDevBySize5Algs.png', facecolor='white',  bbox_inches='tight')
# Out:
# Index(['size_category', 'wf_name', 'inp_size', 'relation', 'ratio',
#        'algorithm'],
#       dtype='object')
#              size_category                    alg_rel     ratio
# 0          Tiny \n (<=200)     MeDiH-BL - dyn_vs_base  0.941925
# 1          Tiny \n (<=200)    MeDiH-BL - stat_vs_base  1.000000
# 2          Tiny \n (<=200)   MeDiH-BL-R - dyn_vs_base  0.857458
# 3          Tiny \n (<=200)  MeDiH-BL-R - stat_vs_base  0.633402
# 4          Tiny \n (<=200)    MeDiH-BLC - dyn_vs_base  0.942239
# 5          Tiny \n (<=200)   MeDiH-BLC - stat_vs_base  0.999993
# 6          Tiny \n (<=200)      MeDiH-I - dyn_vs_base  0.869634
# 7          Tiny \n (<=200)     MeDiH-I - stat_vs_base  0.916383
# 8          Tiny \n (<=200)     MeDiH-MM - dyn_vs_base  0.894713
# 9          Tiny \n (<=200)    MeDiH-MM - stat_vs_base  0.613960
# 10    Small \n (1000-4000)     MeDiH-BL - dyn_vs_base  0.941581
# 11    Small \n (1000-4000)    MeDiH-BL - stat_vs_base  1.000000
# 12    Small \n (1000-4000)   MeDiH-BL-R - dyn_vs_base  0.925967
# 13    Small \n (1000-4000)  MeDiH-BL-R - stat_vs_base  0.358384
# 14    Small \n (1000-4000)    MeDiH-BLC - dyn_vs_base  0.943605
# 15    Small \n (1000-4000)   MeDiH-BLC - stat_vs_base  1.000144
# 16    Small \n (1000-4000)      MeDiH-I - dyn_vs_base  0.936796
# 17    Small \n (1000-4000)     MeDiH-I - stat_vs_base  0.814238
# 18    Small \n (1000-4000)     MeDiH-MM - dyn_vs_base  0.937260
# 19    Small \n (1000-4000)    MeDiH-MM - stat_vs_base  0.304524
# 20  Medium \n (8000-10000)     MeDiH-BL - dyn_vs_base  0.928528
# 21  Medium \n (8000-10000)    MeDiH-BL - stat_vs_base  1.000000
# 22  Medium \n (8000-10000)   MeDiH-BL-R - dyn_vs_base  0.924478
# 23  Medium \n (8000-10000)  MeDiH-BL-R - stat_vs_base  0.362571
# 24  Medium \n (8000-10000)    MeDiH-BLC - dyn_vs_base  0.925470
# 25  Medium \n (8000-10000)   MeDiH-BLC - stat_vs_base  0.999721
# 26  Medium \n (8000-10000)      MeDiH-I - dyn_vs_base  0.922691
# 27  Medium \n (8000-10000)     MeDiH-I - stat_vs_base  0.821146
# 28  Medium \n (8000-10000)     MeDiH-MM - dyn_vs_base  0.932116
# 29  Medium \n (8000-10000)    MeDiH-MM - stat_vs_base  0.303594
# 30  Large \n (15000-20000)     MeDiH-BL - dyn_vs_base  0.918194
# 31  Large \n (15000-20000)    MeDiH-BL - stat_vs_base  1.000000
# 32  Large \n (15000-20000)   MeDiH-BL-R - dyn_vs_base  0.921967
# 33  Large \n (15000-20000)  MeDiH-BL-R - stat_vs_base  0.362399
# 34  Large \n (15000-20000)    MeDiH-BLC - dyn_vs_base  0.917666
# 35  Large \n (15000-20000)   MeDiH-BLC - stat_vs_base  0.999602
# 36  Large \n (15000-20000)      MeDiH-I - dyn_vs_base  0.914630
# 37  Large \n (15000-20000)     MeDiH-I - stat_vs_base  0.816387
# 38  Large \n (15000-20000)     MeDiH-MM - dyn_vs_base  0.925070
# 39  Large \n (15000-20000)    MeDiH-MM - stat_vs_base  0.304561
# 40   Huge \n (25000-30000)     MeDiH-BL - dyn_vs_base  0.912958
# 41   Huge \n (25000-30000)    MeDiH-BL - stat_vs_base  1.000000
# 42   Huge \n (25000-30000)   MeDiH-BL-R - dyn_vs_base  0.929879
# 43   Huge \n (25000-30000)  MeDiH-BL-R - stat_vs_base  0.356157
# 44   Huge \n (25000-30000)    MeDiH-BLC - dyn_vs_base  0.912684
# 45   Huge \n (25000-30000)   MeDiH-BLC - stat_vs_base  0.999914
# 46   Huge \n (25000-30000)      MeDiH-I - dyn_vs_base  0.912595
# 47   Huge \n (25000-30000)     MeDiH-I - stat_vs_base  0.808297
# 48   Huge \n (25000-30000)     MeDiH-MM - dyn_vs_base  0.923186
# 49   Huge \n (25000-30000)    MeDiH-MM - stat_vs_base  0.303024
# alg_rel
# MeDiH-BL - dyn_vs_base       0.928562
# MeDiH-BL - stat_vs_base      1.000000
# MeDiH-BL-R - dyn_vs_base     0.911527
# MeDiH-BL-R - stat_vs_base    0.402949
# MeDiH-BLC - dyn_vs_base      0.928247
# MeDiH-BLC - stat_vs_base     0.999875
# MeDiH-I - dyn_vs_base        0.910987
# MeDiH-I - stat_vs_base       0.834340
# MeDiH-MM - dyn_vs_base       0.922350
# MeDiH-MM - stat_vs_base      0.349817
# Name: ratio, dtype: float64

# %%
# %run NewChartsCommon.ipynb
plot_df_nodev = build_plot_df_size_categories(merged_df_OurProc50)

plotDynVsBaseCustomLegend(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')
plt.savefig(f'50DevBySize5Algs.png', facecolor='white',  bbox_inches='tight')
# Out:
#              size_category                    alg_rel     ratio
# 0          Tiny \n (<=200)     MeDiH-BL - dyn_vs_base  1.072914
# 1          Tiny \n (<=200)    MeDiH-BL - stat_vs_base  1.000000
# 2          Tiny \n (<=200)   MeDiH-BL-R - dyn_vs_base  1.061367
# 3          Tiny \n (<=200)  MeDiH-BL-R - stat_vs_base  0.668190
# 4          Tiny \n (<=200)    MeDiH-BLC - dyn_vs_base  1.023404
# 5          Tiny \n (<=200)   MeDiH-BLC - stat_vs_base  0.997504
# 6          Tiny \n (<=200)      MeDiH-I - dyn_vs_base  1.012528
# 7          Tiny \n (<=200)     MeDiH-I - stat_vs_base  0.913223
# 8          Tiny \n (<=200)     MeDiH-MM - dyn_vs_base  0.996021
# 9          Tiny \n (<=200)    MeDiH-MM - stat_vs_base  0.655512
# 10    Small \n (1000-4000)     MeDiH-BL - dyn_vs_base  1.064177
# 11    Small \n (1000-4000)    MeDiH-BL - stat_vs_base  1.000000
# 12    Small \n (1000-4000)   MeDiH-BL-R - dyn_vs_base  1.055149
# 13    Small \n (1000-4000)  MeDiH-BL-R - stat_vs_base  0.376255
# 14    Small \n (1000-4000)    MeDiH-BLC - dyn_vs_base  1.063919
# 15    Small \n (1000-4000)   MeDiH-BLC - stat_vs_base  1.009767
# 16    Small \n (1000-4000)      MeDiH-I - dyn_vs_base  1.066684
# 17    Small \n (1000-4000)     MeDiH-I - stat_vs_base  0.826239
# 18    Small \n (1000-4000)     MeDiH-MM - dyn_vs_base  1.075654
# 19    Small \n (1000-4000)    MeDiH-MM - stat_vs_base  0.319320
# 20  Medium \n (8000-10000)     MeDiH-BL - dyn_vs_base  1.196527
# 21  Medium \n (8000-10000)    MeDiH-BL - stat_vs_base  1.000000
# 22  Medium \n (8000-10000)   MeDiH-BL-R - dyn_vs_base  1.173324
# 23  Medium \n (8000-10000)  MeDiH-BL-R - stat_vs_base  0.345827
# 24  Medium \n (8000-10000)    MeDiH-BLC - dyn_vs_base  1.173117
# 25  Medium \n (8000-10000)   MeDiH-BLC - stat_vs_base  1.001953
# 26  Medium \n (8000-10000)      MeDiH-I - dyn_vs_base  1.165785
# 27  Medium \n (8000-10000)     MeDiH-I - stat_vs_base  0.804309
# 28  Medium \n (8000-10000)     MeDiH-MM - dyn_vs_base  1.165735
# 29  Medium \n (8000-10000)    MeDiH-MM - stat_vs_base  0.287651
# 30  Large \n (15000-20000)     MeDiH-BL - dyn_vs_base  1.228000
# 31  Large \n (15000-20000)    MeDiH-BL - stat_vs_base  1.000000
# 32  Large \n (15000-20000)   MeDiH-BL-R - dyn_vs_base  1.186318
# 33  Large \n (15000-20000)  MeDiH-BL-R - stat_vs_base  0.350693
# 34  Large \n (15000-20000)    MeDiH-BLC - dyn_vs_base  1.223405
# 35  Large \n (15000-20000)   MeDiH-BLC - stat_vs_base  0.993862
# 36  Large \n (15000-20000)      MeDiH-I - dyn_vs_base  1.209394
# 37  Large \n (15000-20000)     MeDiH-I - stat_vs_base  0.802875
# 38  Large \n (15000-20000)     MeDiH-MM - dyn_vs_base  1.176213
# 39  Large \n (15000-20000)    MeDiH-MM - stat_vs_base  0.296276
# 40   Huge \n (25000-30000)     MeDiH-BL - dyn_vs_base  1.207725
# 41   Huge \n (25000-30000)    MeDiH-BL - stat_vs_base  1.000000
# 42   Huge \n (25000-30000)   MeDiH-BL-R - dyn_vs_base  1.188721
# 43   Huge \n (25000-30000)  MeDiH-BL-R - stat_vs_base  0.351099
# 44   Huge \n (25000-30000)    MeDiH-BLC - dyn_vs_base  1.222452
# 45   Huge \n (25000-30000)   MeDiH-BLC - stat_vs_base  1.012417
# 46   Huge \n (25000-30000)      MeDiH-I - dyn_vs_base  1.208174
# 47   Huge \n (25000-30000)     MeDiH-I - stat_vs_base  0.788512
# 48   Huge \n (25000-30000)     MeDiH-MM - dyn_vs_base  1.164213
# 49   Huge \n (25000-30000)    MeDiH-MM - stat_vs_base  0.290021
# alg_rel
# MeDiH-BL - dyn_vs_base       1.151685
# MeDiH-BL - stat_vs_base      1.000000
# MeDiH-BL-R - dyn_vs_base     1.131294
# MeDiH-BL-R - stat_vs_base    0.403571
# MeDiH-BLC - dyn_vs_base      1.138203
# MeDiH-BLC - stat_vs_base     1.003076
# MeDiH-I - dyn_vs_base        1.129670
# MeDiH-I - stat_vs_base       0.825871
# MeDiH-MM - dyn_vs_base       1.113299
# MeDiH-MM - stat_vs_base      0.348947
# Name: ratio, dtype: float64
