# %%
# %run NewChartsWorking.ipynb
# Out:
# ./output-20-02/merged/*.txt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/workspace/repro-paper-51-ALENEX26-/NotebooksPerFigureType/NewChartsWorking.ipynb in <module>
#       6 dfs=read_dfs(path,patterndevs, 2)
#       7 labels = ['A1', 'A2', 'A3', 'BASE']
# ----> 8 dfsVar1 = [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')]]
#       9 #print(dfsVar1)
#      10
#
# KeyError: ('A1', 'ndev')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_321313/4088262980.py in <module>
# ----> 1 get_ipython().run_line_magic('run', 'NewChartsWorking.ipynb')
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
# ...

# %%
path = "./output-1-04/merged/*.txt"
print(path)

print("\n-----------------\n 1-04 \n With A4 and A5, all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')], dfs[('A4','ndev')], dfs[('A5','ndev')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)


patterndevs = r'^(BASE|A\d+)-(\d\ddev)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev')], dfs[('A2','50dev')], dfs[('A3','50dev')], dfs[('A4','50dev')], dfs[('A5','50dev')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)


printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)
# Out:
# ./output-1-04/merged/*.txt
#
# -----------------
#  1-04
#  With A4 and A5, all deviations
#
#
# ------------------------------------
#
# online_to_offline_A1 1.0243343392583655
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 1.0131854880311861
# offline_to_base_A2 1.0217877346192448
# online_to_offline_A2 50-vars 0.8993316679582378
# offline_to_base_A2 50-vars 1.0032577931124456
#
# ------------------------------------
#
# online_to_offline_A3 0.970148224961049
# offline_to_base_A3 1.0561570198369168
# online_to_offline_A3 50-vars 0.8802889323069724
# offline_to_base_A3 50-vars 1.0479615676874259
#
# ------------------------------------
#
# online_to_offline_A4 0.7017914475188471
# offline_to_base_A4 1.4888943198877749
# online_to_offline_A4 50-vars 0.6422001156772134
# offline_to_base_A4 50-vars 1.4724499124795492
#
# ------------------------------------
#
# online_to_offline_A5 0.6369836838525986
# offline_to_base_A5 1.6571583288079197
# ...

# %%
# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
print(plot_df_nodev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])
#plt.savefig(f'NoDevBySize5Algs.png', facecolor='white',  bbox_inches='tight')
# Out:
# /tmp/ipykernel_19476/245252065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
# /tmp/ipykernel_19476/245252065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
# size           int64
# wf_name       object
# inp_size       int64
# relation      object
# ratio        float64
# ...

# %%
# %run NewChartsCommon.ipynb
merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# size           int64
# wf_name       object
# inp_size       int64
# relation      object
# ratio        float64
# algorithm     object
# dtype: object
#     size                    alg_rel     ratio
# 0     50     MeDiH-BL - dyn_vs_base  1.076439
# 1     50    MeDiH-BL - stat_vs_base  1.000000
# 2     50   MeDiH-BL-R - dyn_vs_base  1.040441
# 3     50  MeDiH-BL-R - stat_vs_base  0.878960
# 4     50    MeDiH-BLC - dyn_vs_base  1.227471
# 5     50   MeDiH-BLC - stat_vs_base  1.005340
# 6     50      MeDiH-I - dyn_vs_base  0.914727
# 7     50     MeDiH-I - stat_vs_base  0.824357
# 8     50     MeDiH-MM - dyn_vs_base  1.044510
# 9     50    MeDiH-MM - stat_vs_base  0.991475
# 10   200     MeDiH-BL - dyn_vs_base  1.099326
# 11   200    MeDiH-BL - stat_vs_base  1.000000
# 12   200   MeDiH-BL-R - dyn_vs_base  0.861346
# 13   200  MeDiH-BL-R - stat_vs_base  0.652026
# 14   200    MeDiH-BLC - dyn_vs_base  0.940573
# 15   200   MeDiH-BLC - stat_vs_base  0.966106
# ...

# %%
path = "./output-3-04/merged/*.txt"
print(path)

print("\n-----------------\n 1-04 \n With A4 and A5, all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')], dfs[('A4','ndev')], dfs[('A5','ndev')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)


patterndevs = r'^(BASE|A\d+)-(\d\ddev)'
dfs=read_dfs(path,patterndevs, 2)


dfsOurProc50 = [dfs[('A1','50dev')], dfs[('A2','50dev')], dfs[('A3','50dev')], dfs[('A4','50dev')], dfs[('A5','50dev')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)



printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)
# Out:
# ./output-3-04/merged/*.txt
#
# -----------------
#  1-04
#  With A4 and A5, all deviations
#
# online_to_offline_A1 1.005929233504002
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 1.0131854880311861
# offline_to_base_A2 1.0034283859247604
# online_to_offline_A2 50-vars 0.897186585028674
# offline_to_base_A2 50-vars 1.0021123053539993
#
# ------------------------------------
#
# online_to_offline_A3 0.970148224961049
# offline_to_base_A3 1.0371801283100883
# online_to_offline_A3 50-vars 0.8727931268281502
# offline_to_base_A3 50-vars 1.0484857661982607
#
# ------------------------------------
#
# online_to_offline_A4 0.7017914475188471
# offline_to_base_A4 1.4621420610164713
# online_to_offline_A4 50-vars 0.6268074789739371
# offline_to_base_A4 50-vars 1.4938118813580112
#
# ------------------------------------
#
# online_to_offline_A5 0.6369836838525986
# offline_to_base_A5 1.6273827241791452
# ...

# %%
# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
print(plot_df_nodev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# size           int64
# wf_name       object
# inp_size       int64
# relation      object
# ratio        float64
# algorithm     object
# dtype: object
#      size                    alg_rel     ratio
# 0      50     MeDiH-BL - dyn_vs_base  0.953642
# 1      50    MeDiH-BL - stat_vs_base  1.000000
# 2      50   MeDiH-BL-R - dyn_vs_base  0.918309
# 3      50  MeDiH-BL-R - stat_vs_base  0.833080
# 4      50    MeDiH-BLC - dyn_vs_base  0.934589
# ..    ...                        ...       ...
# 75  15000   MeDiH-BLC - stat_vs_base  1.000414
# 76  15000      MeDiH-I - dyn_vs_base  1.000348
# 77  15000     MeDiH-I - stat_vs_base  0.672118
# 78  15000     MeDiH-MM - dyn_vs_base  1.001432
# 79  15000    MeDiH-MM - stat_vs_base  0.971921
#
# [80 rows x 3 columns]
# alg_rel
# MeDiH-BL - dyn_vs_base       0.998956
# MeDiH-BL - stat_vs_base      1.000000
# MeDiH-BL-R - dyn_vs_base     0.975801
# MeDiH-BL-R - stat_vs_base    0.601849
# MeDiH-BLC - dyn_vs_base      0.990931
# ...

# %%
path = "./output-3-04-MM/merged/*.txt"
print(path)

print("\n-----------------\n 1-04 \n With A4 and A5, all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')], dfs[('A4','ndev')], dfs[('A5','ndev')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)

patterndevs = r'^(BASE|A\d+)-(\d\ddev)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev')], dfs[('A2','50dev')], dfs[('A3','50dev')], dfs[('A4','50dev')], dfs[('A5','50dev')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)


printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)
# Out:
# ./output-3-04-MM/merged/*.txt
#
# -----------------
#  1-04
#  With A4 and A5, all deviations
#
#
# ------------------------------------
#
# online_to_offline_A1 0.7867929243793177
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 0.9333943395953009
# offline_to_base_A2 0.8423117783058595
# online_to_offline_A2 50-vars 0.8248746273684507
# offline_to_base_A2 50-vars 0.8411085602014778
#
# ------------------------------------
#
# online_to_offline_A3 0.6419546391371591
# offline_to_base_A3 1.2200927895183047
# online_to_offline_A3 50-vars 0.5729458399540065
# offline_to_base_A3 50-vars 1.2125206500711732
#
# ------------------------------------
#
# online_to_offline_A4 0.8351614633480884
# offline_to_base_A4 0.9427222164523836
# online_to_offline_A4 50-vars 0.7369360052379874
# offline_to_base_A4 50-vars 0.9462928586568087
#
# ------------------------------------
#
# online_to_offline_A5 0.6968649921379683
# ...

# %%
# %run NewChartsCommon.ipynb
#merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
#merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
#merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


#merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
#merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
#merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
#                  wf_name      inp_size       ms_1_A1       ms_2_A1  dur_1_A1  \
# 0                  eager   19075314980  2.978819e+08  3.134998e+08  0.010623
# 1         eager_1000.dot   25705994498  1.383002e+09  4.363581e+09  0.277857
# 2     methylseq_1000.dot  110641579976  2.699138e+09  2.763163e+09  0.147870
# 3        chipseq_200.dot    5058052541  3.872011e+07  5.008163e+07  0.017705
# 4     methylseq_1000.dot    6273818718  2.814700e+08  3.096290e+08  0.093015
# ..                   ...           ...           ...           ...       ...
# 163                eager   19132169434  2.993307e+08  3.147322e+08  0.010676
# 164  methylseq_10000.dot   17027257018  6.698951e+09  6.246699e+09  1.196998
# 165        eager_200.dot    8330435694  1.592798e+08  2.182155e+08  0.035352
# 166              atacseq   11809629756  5.458989e+07  5.304185e+07  0.003202
# 167    chipseq_10000.dot    4807293396  1.760955e+09  2.101085e+09  1.305515
#
# ...

# %%
# %run NewChartsCommon.ipynb
path = "./output-9-04/merged/*.txt"
print(path)

print("\n-----------------\n 9-04 \n REGULAR RANDOM DAGS all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev~NoMM)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev~NoMM')], dfs[('A2','ndev~NoMM')], dfs[('A3','ndev~NoMM')], dfs[('A4','ndev~NoMM')], dfs[('A5','ndev~NoMM')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)
merged_df_varOurProcNoDev =merged_df_varOurProcNoDev[~merged_df_varOurProcNoDev['wf_name'].str.contains('lowio|long|wide')]


patterndevs = r'^(BASE|A\d+)-(\d\ddev~NoMM)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev~NoMM')], dfs[('A2','50dev~NoMM')], dfs[('A3','50dev~NoMM')], dfs[('A4','50dev~NoMM')], dfs[('A5','50dev~NoMM')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)
merged_df_OurProc50 =merged_df_OurProc50[~merged_df_OurProc50['wf_name'].str.contains('lowio|long|wide')]

printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)
# Out:
# ./output-9-04/merged/*.txt
#
# -----------------
#  9-04
#  REGULAR RANDOM DAGS all deviations
#
#
# ------------------------------------
#
# online_to_offline_A1 1.005929233504002
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 1.0131854880311861
# offline_to_base_A2 1.0034283859247604
# online_to_offline_A2 50-vars 0.897186585028674
# offline_to_base_A2 50-vars 1.0021123053539993
#
# ------------------------------------
#
# online_to_offline_A3 0.970148224961049
# offline_to_base_A3 1.0371801283100883
# online_to_offline_A3 50-vars 0.8727931268281502
# offline_to_base_A3 50-vars 1.0484857661982607
#
# ------------------------------------
#
# online_to_offline_A4 0.7017914475188471
# offline_to_base_A4 1.4621420610164713
# online_to_offline_A4 50-vars 0.6268074789739371
# offline_to_base_A4 50-vars 1.4938118813580112
#
# ------------------------------------
#
# online_to_offline_A5 0.6369836838525986
# offline_to_base_A5 1.6273827241791452
# ...

# %%
# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
#print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
#print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
#      size                    alg_rel     ratio
# 0      50     MeDiH-BL - dyn_vs_base  0.953642
# 1      50    MeDiH-BL - stat_vs_base  1.000000
# 2      50   MeDiH-BL-R - dyn_vs_base  0.918309
# 3      50  MeDiH-BL-R - stat_vs_base  0.833080
# 4      50    MeDiH-BLC - dyn_vs_base  0.934589
# ..    ...                        ...       ...
# 75  15000   MeDiH-BLC - stat_vs_base  1.000414
# 76  15000      MeDiH-I - dyn_vs_base  1.000348
# 77  15000     MeDiH-I - stat_vs_base  0.672118
# 78  15000     MeDiH-MM - dyn_vs_base  1.001432
# 79  15000    MeDiH-MM - stat_vs_base  0.971921
#
# [80 rows x 3 columns]
# alg_rel
# MeDiH-BL - dyn_vs_base       0.998956
# MeDiH-BL - stat_vs_base      1.000000
# MeDiH-BL-R - dyn_vs_base     0.975801
# MeDiH-BL-R - stat_vs_base    0.601849
# MeDiH-BLC - dyn_vs_base      0.990931
# MeDiH-BLC - stat_vs_base     1.001245
# MeDiH-I - dyn_vs_base        0.988297
# MeDiH-I - stat_vs_base       0.671109
# MeDiH-MM - dyn_vs_base       0.998743
# ...

# %%
# %run NewChartsCommon.ipynb
path = "./output-9-04/merged/*.txt"
print(path)

print("\n-----------------\n 9-04 \n LONG RANDOM DAGS all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev~NoMM)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev~NoMM')], dfs[('A2','ndev~NoMM')], dfs[('A3','ndev~NoMM')], dfs[('A4','ndev~NoMM')], dfs[('A5','ndev~NoMM')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)
merged_df_varOurProcNoDev =merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['wf_name'].str.contains('long')]


patterndevs = r'^(BASE|A\d+)-(\d\ddev~NoMM)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev~NoMM')], dfs[('A2','50dev~NoMM')], dfs[('A3','50dev~NoMM')], dfs[('A4','50dev~NoMM')], dfs[('A5','50dev~NoMM')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)
merged_df_OurProc50 =merged_df_OurProc50[merged_df_OurProc50['wf_name'].str.contains('long')]

printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)


# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
#print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
#print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# ./output-9-04/merged/*.txt
#
# -----------------
#  9-04
#  LONG RANDOM DAGS all deviations
#
#
# ------------------------------------
#
# online_to_offline_A1 1.0082695003208215
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 1.0108808804917806
# offline_to_base_A2 0.9999990488820811
# online_to_offline_A2 50-vars 0.8456955686539476
# offline_to_base_A2 50-vars 0.9952857437238516
#
# ------------------------------------
#
# online_to_offline_A3 1.0361046998518273
# offline_to_base_A3 1.0007125713063032
# online_to_offline_A3 50-vars 0.8576103114420843
# offline_to_base_A3 50-vars 1.0001141082827263
#
# ------------------------------------
#
# online_to_offline_A4 1.0417325229497185
# offline_to_base_A4 1.0004761167099732
# online_to_offline_A4 50-vars 0.8734380037518431
# offline_to_base_A4 50-vars 0.9976144366713446
#
# ------------------------------------
#
# online_to_offline_A5 1.0467929554794486
# offline_to_base_A5 1.0019505742894506
# ...

# %%
# %run NewChartsCommon.ipynb
path = "./output-9-04/merged/*.txt"
print(path)

print("\n-----------------\n 9-04 \n WIDE RANDOM DAGS all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev~NoMM)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev~NoMM')], dfs[('A2','ndev~NoMM')], dfs[('A3','ndev~NoMM')], dfs[('A4','ndev~NoMM')], dfs[('A5','ndev~NoMM')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)
merged_df_varOurProcNoDev =merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['wf_name'].str.contains('wide')]

print(merged_df_varOurProcNoDev)


patterndevs = r'^(BASE|A\d+)-(\d\ddev~NoMM)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev~NoMM')], dfs[('A2','50dev~NoMM')], dfs[('A3','50dev~NoMM')], dfs[('A4','50dev~NoMM')], dfs[('A5','50dev~NoMM')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)
merged_df_OurProc50 =merged_df_OurProc50[merged_df_OurProc50['wf_name'].str.contains('wide')]

printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)


# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
#print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
#print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# ./output-9-04/merged/*.txt
#
# -----------------
#  9-04
#  WIDE RANDOM DAGS all deviations
#
#                  wf_name  inp_size       ms_1_A1       ms_2_A1  dur_1_A1  \
# 7    dag_1000_wide_4.dot         1  8.552894e+09  8.639191e+09  1.418036
# 8    dag_1000_wide_3.dot         1  8.464915e+09  8.251416e+09  1.406306
# 11     dag_50_wide_4.dot         1  1.268615e+08  1.257740e+08  0.011228
# 13    dag_200_wide_1.dot         1  6.457740e+08  4.738643e+08  0.069961
# 16     dag_50_wide_0.dot         1  1.616487e+08  1.611818e+08  0.010015
# 19    dag_200_wide_0.dot         1  5.364409e+08  5.866765e+08  0.063132
# 24     dag_50_wide_3.dot         1  1.376000e+08  1.437985e+08  0.011343
# 42    dag_200_wide_3.dot         1  5.793335e+08  5.422491e+08  0.097831
# 43    dag_200_wide_4.dot         1  5.272770e+08  5.528096e+08  0.085695
# 64    dag_200_wide_2.dot         1  4.779649e+08  4.999694e+08  0.057995
# 77   dag_1000_wide_1.dot         1  7.911677e+09  8.718966e+09  1.407391
# ...

# %%
# %run NewChartsCommon.ipynb
path = "./output-9-04/merged/*.txt"
print(path)

print("\n-----------------\n 9-04 \n LOWIO RANDOM DAGS all deviations \n ")
patterndevs = r'^(BASE|A\d+)-(ndev~NoMM)'

dfs=read_dfs(path,patterndevs, 2)
#print(dfs)
labels = ['A1', 'A2', 'A3','A4', 'A5']

dfsVarOurProcNoDev= [dfs[('A1','ndev~NoMM')], dfs[('A2','ndev~NoMM')], dfs[('A3','ndev~NoMM')], dfs[('A4','ndev~NoMM')], dfs[('A5','ndev~NoMM')]]#
merged_df_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)
merged_df_varOurProcNoDev =merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['wf_name'].str.contains('lowio')]

print(merged_df_varOurProcNoDev)


patterndevs = r'^(BASE|A\d+)-(\d\ddev~NoMM)'
dfs=read_dfs(path,patterndevs, 2)

print("\n------------------------------------\n")

dfsOurProc50 = [dfs[('A1','50dev~NoMM')], dfs[('A2','50dev~NoMM')], dfs[('A3','50dev~NoMM')], dfs[('A4','50dev~NoMM')], dfs[('A5','50dev~NoMM')]]
merged_df_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)
merged_df_OurProc50 =merged_df_OurProc50[merged_df_OurProc50['wf_name'].str.contains('lowio')]

printRelScores(merged_df_varOurProcNoDev, merged_df_OurProc50)


# %run NewChartsCommon.ipynb
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_varOurProcNoDev['size'] = merged_df_varOurProcNoDev['size'].astype(int)
merged_df_varOurProcNoDev = merged_df_varOurProcNoDev[merged_df_varOurProcNoDev['size'] != 100]
plot_df_nodev = buld_plot_df(merged_df_varOurProcNoDev)
#print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_df_OurProc50['size'] = merged_df_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_OurProc50['size'] = merged_df_OurProc50['size'].astype(int)
merged_df_OurProc50 = merged_df_OurProc50[merged_df_OurProc50['size'] != 100]
plot_df_50dev = buld_plot_df(merged_df_OurProc50)
#print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# ./output-9-04/merged/*.txt
#
# -----------------
#  9-04
#  LOWIO RANDOM DAGS all deviations
#
#                          wf_name  inp_size       ms_1_A1       ms_2_A1  \
# 0     dag_lowio_50_general_0.dot         1  2.095097e+06  5.359945e+05
# 2    dag_lowio_200_general_4.dot         1  9.095224e+06  1.330221e+06
# 20    dag_lowio_50_general_4.dot         1  2.483498e+06  4.613329e+05
# 34   dag_lowio_200_general_3.dot         1  8.322736e+06  1.295838e+06
# 38    dag_lowio_50_general_2.dot         1  2.094481e+06  4.424211e+05
# 39   dag_lowio_100_general_2.dot         1  4.300823e+06  8.059624e+05
# 40   dag_lowio_100_general_4.dot         1  4.725609e+06  7.416275e+05
# 60    dag_lowio_50_general_1.dot         1  5.414030e+05  5.122374e+05
# 74   dag_lowio_100_general_1.dot         1  4.947457e+06  8.027064e+05
# 81   dag_lowio_200_general_1.dot         1  8.706016e+06  1.340414e+06
# 84   dag_lowio_100_general_3.dot         1  4.154217e+06  7.496994e+05
# ...

# %%
# %run NewChartsCommon.ipynb
labels = ['A1', 'A2', 'A3','A4', 'A5']
path = "./output-allrands/merged/*.txt" #"./output-15-04-newrandom/merged/*.txt"

patterndevs = r'^(BASE|A\d+)-(ndev)'
dfs=read_dfs(path,patterndevs, 2)


dfsVarOurProcNoDev= [dfs[('A1','ndev')], dfs[('A2','ndev')], dfs[('A3','ndev')], dfs[('A4','ndev')], dfs[('A5','ndev')]]#
merged_rands_varOurProcNoDev = merge_correct_columnsNoMs3(dfsVarOurProcNoDev, labels)

patterndevs = r'^(BASE|A\d+)-(\d\ddev)'
dfs=read_dfs(path,patterndevs, 2)
dfsOurProc50 = [dfs[('A1','50dev')], dfs[('A2','50dev')], dfs[('A3','50dev')], dfs[('A4','50dev')], dfs[('A5','50dev')]]
merged_rands_OurProc50= merge_correct_columnsNoMs3(dfsOurProc50, labels)


print(merged_rands_varOurProcNoDev.columns)
print(merged_rands_OurProc50.columns)

merged_rands_varOurProcNoDev['size'] = merged_rands_varOurProcNoDev['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_varOurProcNoDev['size'] = merged_rands_varOurProcNoDev['size'].astype(int)
merged_rands_OurProc50['size'] = merged_rands_OurProc50['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_OurProc50['size'] = merged_rands_OurProc50['size'].astype(int)


merged_rands_varOurProcNoDev['deviations'] = False
merged_rands_OurProc50['deviations'] = True
# Out:
# Index(['wf_name', 'inp_size', 'ms_1_A1', 'ms_2_A1', 'dur_1_A1', 'dur_2_A1',
#        'ms_1_A2', 'ms_2_A2', 'dur_1_A2', 'dur_2_A2', 'ms_1_A3', 'ms_2_A3',
#        'dur_1_A3', 'dur_2_A3', 'ms_1_A4', 'ms_2_A4', 'dur_1_A4', 'dur_2_A4',
#        'ms_1_A5', 'ms_2_A5', 'dur_1_A5', 'dur_2_A5', 'size'],
#       dtype='object')
# Index(['wf_name', 'inp_size', 'ms_1_A1', 'ms_2_A1', 'dur_1_A1', 'dur_2_A1',
#        'ms_1_A2', 'ms_2_A2', 'dur_1_A2', 'dur_2_A2', 'ms_1_A3', 'ms_2_A3',
#        'dur_1_A3', 'dur_2_A3', 'ms_1_A4', 'ms_2_A4', 'dur_1_A4', 'dur_2_A4',
#        'ms_1_A5', 'ms_2_A5', 'dur_1_A5', 'dur_2_A5', 'size'],
#       dtype='object')

# %%
#--------------------------------
#    ONLY RANDOM DAGS
#----------------------------------------

merged_df_nodev_norm =merged_rands_varOurProcNoDev[~merged_rands_varOurProcNoDev['wf_name'].str.contains('long|wide')].copy()
merged_df_50_norm =merged_rands_OurProc50[~merged_rands_OurProc50['wf_name'].str.contains('lowio|long|wide')].copy()

printRelScores(merged_rands_varOurProcNoDev, merged_rands_OurProc50)


# %run NewChartsCommon.ipynb
merged_df_nodev_norm['size'] = merged_df_nodev_norm['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_nodev_norm['size'] = merged_df_nodev_norm['size'].astype(int)
merged_df_nodev_norm = merged_df_nodev_norm[merged_df_nodev_norm['size'] != 100]
plot_df_nodev = build_plot_df_size_categories(merged_df_nodev_norm)
#print(merged_df_varOurProcNoDev)

plotDynVsBaseCustomLegend(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')


merged_df_50_norm['size'] = merged_df_50_norm['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_df_50_norm['size'] = merged_df_50_norm['size'].astype(int)
merged_df_50_norm = merged_df_50_norm[merged_df_50_norm['size'] != 100]
plot_df_50dev = build_plot_df_size_categories(merged_df_50_norm)
#print(plot_df_50dev.dtypes)

plotDynVsBaseCustomLegend(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')
# Out:
# online_to_offline_A1 0.9392304608469226
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 0.9494261840011357
# offline_to_base_A2 0.9911379131973196
# online_to_offline_A2 50-vars 0.8270691293202608
# offline_to_base_A2 50-vars 0.9913493228378764
#
# ------------------------------------
#
# online_to_offline_A3 0.8412764368351342
# offline_to_base_A3 1.1151479041276684
# online_to_offline_A3 50-vars 0.7469275977027717
# offline_to_base_A3 50-vars 1.0994126079062885
#
# ------------------------------------
#
# online_to_offline_A4 0.6183509476654273
# offline_to_base_A4 1.5295755639196282
# online_to_offline_A4 50-vars 0.5755693243080872
# offline_to_base_A4 50-vars 1.4492652609521754
#
# ------------------------------------
#
# online_to_offline_A5 0.5654805357566192
# offline_to_base_A5 1.705830466665701
# online_to_offline_A5 50-vars 0.5326964538621273
# offline_to_base_A5 50-vars 1.585445303486134
# ...

# %%
#--------------------------------
#    ONLY WIDE RANDOM DAGS
#----------------------------------------

merged_rands_nodev_wide =merged_rands_varOurProcNoDev[merged_rands_varOurProcNoDev['wf_name'].str.contains('wide')].copy()
merged_rands_50_wide =merged_rands_OurProc50[merged_rands_OurProc50['wf_name'].str.contains('wide')].copy()

printRelScores(merged_rands_nodev_wide, merged_rands_50_wide)


# %run NewChartsCommon.ipynb
merged_rands_nodev_wide['size'] = merged_rands_nodev_wide['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_nodev_wide['size'] = merged_rands_nodev_wide['size'].astype(int)
merged_rands_nodev_wide = merged_rands_nodev_wide[merged_rands_nodev_wide['size'] != 100]
plot_df_nodev = build_plot_df_size_categories(merged_rands_nodev_wide)
#print(merged_df_varOurProcNoDev)

plotDynVsBaseCustomLegend(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')


merged_rands_50_wide['size'] = merged_rands_50_wide['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_50_wide['size'] = merged_rands_50_wide['size'].astype(int)
merged_rands_50_wide = merged_rands_50_wide[merged_rands_50_wide['size'] != 100]
plot_df_50dev = build_plot_df_size_categories(merged_rands_50_wide)
#print(plot_df_50dev.dtypes)

plotDynVsBaseCustomLegend(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'], 'size_category')
# Out:
# online_to_offline_A1 0.8269628158607303
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 0.8533088655159227
# offline_to_base_A2 0.971337169651424
# online_to_offline_A2 50-vars 0.745220276319767
# offline_to_base_A2 50-vars 0.9827537041402582
#
# ------------------------------------
#
# online_to_offline_A3 0.6308864315534088
# offline_to_base_A3 1.2908815845880044
# online_to_offline_A3 50-vars 0.5729413204060236
# offline_to_base_A3 50-vars 1.2878496058265227
#
# ------------------------------------
#
# online_to_offline_A4 0.3521306611591212
# offline_to_base_A4 2.34772378620209
# online_to_offline_A4 50-vars 0.3442519202895285
# offline_to_base_A4 50-vars 2.2113903258746936
#
# ------------------------------------
#
# online_to_offline_A5 0.2892441245389685
# offline_to_base_A5 3.005382082304157
# online_to_offline_A5 50-vars 0.28341666010757166
# offline_to_base_A5 50-vars 2.765622338050929
# ...

# %%
#--------------------------------
#    ONLY LONG RANDOM DAGS
#----------------------------------------
merged_rands_nodev_long=merged_rands_varOurProcNoDev[merged_rands_varOurProcNoDev['wf_name'].str.contains('long')].copy()
merged_rands_50_long =merged_rands_OurProc50[merged_rands_OurProc50['wf_name'].str.contains('long')].copy()

printRelScores(merged_rands_varOurProcNoDev, merged_rands_OurProc50)


# %run NewChartsCommon.ipynb
merged_rands_nodev_long['size'] = merged_rands_nodev_long['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_nodev_long['size'] = merged_rands_nodev_long['size'].astype(int)
merged_rands_nodev_long = merged_rands_nodev_long[merged_rands_nodev_long['size'] != 100]
plot_df_nodev = buld_plot_df(merged_rands_nodev_long)
#print(merged_df_varOurProcNoDev)

plotDynAndStaticVsBaseNoInset(plot_df_nodev,"no deviations", "title",['stat_vs_base', 'dyn_vs_base'])


merged_rands_50_long['size'] = merged_rands_50_long['wf_name'].str.extract(r'_(\d+)_')[0].fillna("100")
merged_rands_50_long['size'] = merged_rands_50_long['size'].astype(int)
merged_rands_50_long = merged_rands_50_long[merged_rands_50_long['size'] != 100]
plot_df_50dev = buld_plot_df(merged_rands_50_long)
#print(plot_df_50dev.dtypes)

plotDynAndStaticVsBaseNoInset(plot_df_50dev,"large deviations", "title",['stat_vs_base', 'dyn_vs_base'])
# Out:
# online_to_offline_A1 0.9392304608469226
# offline_to_base_A1 1.0
#
# ------------------------------------
#
# online_to_offline_A2 0.9494261840011357
# offline_to_base_A2 0.9911379131973196
# online_to_offline_A2 50-vars 0.8317633355222639
# offline_to_base_A2 50-vars 0.990158652930682
#
# ------------------------------------
#
# online_to_offline_A3 0.8412764368351342
# offline_to_base_A3 1.1151479041276684
# online_to_offline_A3 50-vars 0.7564985057681313
# offline_to_base_A3 50-vars 1.0928644561419831
#
# ------------------------------------
#
# online_to_offline_A4 0.6183509476654273
# offline_to_base_A4 1.5295755639196282
# online_to_offline_A4 50-vars 0.6001710592170175
# offline_to_base_A4 50-vars 1.3997962146727752
#
# ------------------------------------
#
# online_to_offline_A5 0.5654805357566192
# offline_to_base_A5 1.705830466665701
# online_to_offline_A5 50-vars 0.5592506747778002
# offline_to_base_A5 50-vars 1.5214881859686262
# ...
